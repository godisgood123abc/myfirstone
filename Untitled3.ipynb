# %%
import pandas as pd

# %%
df_auto=pd.read_excel('/content/iris.xls')

# %%
df_auto
# Out:
#       SL   SW   PL   PW  Classification
# 0    5.1  3.5  1.4  0.2     Iris-setosa
# 1    4.9  3.0  1.4  0.2     Iris-setosa
# 2    4.7  3.2  1.3  0.2     Iris-setosa
# 3    4.6  3.1  1.5  0.2     Iris-setosa
# 4    5.0  3.6  1.4  0.2     Iris-setosa
# ..   ...  ...  ...  ...             ...
# 145  6.7  3.0  5.2  2.3  Iris-virginica
# 146  6.3  2.5  5.0  1.9  Iris-virginica
# 147  6.5  3.0  5.2  2.0  Iris-virginica
# 148  6.2  3.4  5.4  2.3  Iris-virginica
# 149  5.9  3.0  5.1  1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# Q1

# %%
df_auto.head()
# Out:
#     SL   SW   PL   PW Classification
# 0  5.1  3.5  1.4  0.2    Iris-setosa
# 1  4.9  3.0  1.4  0.2    Iris-setosa
# 2  4.7  3.2  1.3  0.2    Iris-setosa
# 3  4.6  3.1  1.5  0.2    Iris-setosa
# 4  5.0  3.6  1.4  0.2    Iris-setosa

# %% [markdown]
# Q2

# %%
df_auto['SL'].mean()
# Out:
# 5.843333333333334

# %%
df_auto['SL'].median()
# Out:
# 5.8

# %%
df_auto['SL'].std()
# Out:
# 0.828066127977863

# %% [markdown]
# Q3

# %%
df_auto[['PW','Classification']].max()
# Out:
# PW                           2.5
# Classification    Iris-virginica
# dtype: object

# %% [markdown]
# Q4

# %%
df_auto.iloc[:,[2]]
# Out:
#       PL
# 0    1.4
# 1    1.4
# 2    1.3
# 3    1.5
# 4    1.4
# ..   ...
# 145  5.2
# 146  5.0
# 147  5.2
# 148  5.4
# 149  5.1
#
# [150 rows x 1 columns]

# %% [markdown]
# Q5

# %%
df_auto.iloc[0]
# Out:
# SL                        5.1
# SW                        3.5
# PL                        1.4
# PW                        0.2
# Classification    Iris-setosa
# Name: 0, dtype: object

# %% [markdown]
# Q6

# %%
df_auto.loc[10]
# Out:
# SL                        5.4
# SW                        3.7
# PL                        1.5
# PW                        0.2
# Classification    Iris-setosa
# Name: 10, dtype: object

# %% [markdown]
# Q7

# %%
df_auto.iloc[:].tail(1)
# Out:
#       SL   SW   PL   PW  Classification
# 149  5.9  3.0  5.1  1.8  Iris-virginica

# %% [markdown]
# Q8

# %%
df_auto.loc[25:30,["PL","PW"]]
# Out:
#      PL   PW
# 25  1.6  0.2
# 26  1.6  0.4
# 27  1.5  0.2
# 28  1.4  0.2
# 29  1.6  0.2
# 30  1.6  0.2

# %% [markdown]
# Q9

# %%
df_auto.iloc[:10,[0,1]].head(10)
# Out:
#     SL   SW
# 0  5.1  3.5
# 1  4.9  3.0
# 2  4.7  3.2
# 3  4.6  3.1
# 4  5.0  3.6
# 5  5.4  3.9
# 6  4.6  3.4
# 7  5.0  3.4
# 8  4.4  2.9
# 9  4.9  3.1

# %% [markdown]
# Q10

# %%
df_auto.loc[1,:]
# Out:
# SL                        4.9
# SW                        3.0
# PL                        1.4
# PW                        0.2
# Classification    Iris-setosa
# Name: 1, dtype: object
