# %%
import pandas as pd

# %%
df_auto=pd.read_excel('/iris.xls')

# %%
df_auto
# Out:
#       SL   SW   PL   PW  Classification
# 0    5.1  3.5  1.4  0.2     Iris-setosa
# 1    4.9  3.0  1.4  0.2     Iris-setosa
# 2    4.7  3.2  1.3  0.2     Iris-setosa
# 3    4.6  3.1  1.5  0.2     Iris-setosa
# 4    5.0  3.6  1.4  0.2     Iris-setosa
# ..   ...  ...  ...  ...             ...
# 145  6.7  3.0  5.2  2.3  Iris-virginica
# 146  6.3  2.5  5.0  1.9  Iris-virginica
# 147  6.5  3.0  5.2  2.0  Iris-virginica
# 148  6.2  3.4  5.4  2.3  Iris-virginica
# 149  5.9  3.0  5.1  1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# Q1

# %%
df_auto.head()
# Out:
#     SL   SW   PL   PW Classification
# 0  5.1  3.5  1.4  0.2    Iris-setosa
# 1  4.9  3.0  1.4  0.2    Iris-setosa
# 2  4.7  3.2  1.3  0.2    Iris-setosa
# 3  4.6  3.1  1.5  0.2    Iris-setosa
# 4  5.0  3.6  1.4  0.2    Iris-setosa

# %% [markdown]
# Q2

# %%
df_auto['SL'].mean()
# Out:
# 5.843333333333334

# %%
df_auto['SL'].median()
# Out:
# 5.8

# %%
df_auto['SL'].std()
# Out:
# 0.828066127977863

# %% [markdown]
# Q3

# %%
df_auto['PW'].max()
# Out:
# 2.5

# %%
df_auto['PL'].max()
# Out:
# 6.9

# %%
df_auto['SW'].max()
# Out:
# 4.4

# %% [markdown]
# Q5

# %%
df_auto.iloc[0]
# Out:
# SL                        5.1
# SW                        3.5
# PL                        1.4
# PW                        0.2
# Classification    Iris-setosa
# Name: 0, dtype: object

# %% [markdown]
# Q6

# %%
df_auto.loc[:10]
# Out:
#      SL   SW   PL   PW Classification
# 0   5.1  3.5  1.4  0.2    Iris-setosa
# 1   4.9  3.0  1.4  0.2    Iris-setosa
# 2   4.7  3.2  1.3  0.2    Iris-setosa
# 3   4.6  3.1  1.5  0.2    Iris-setosa
# 4   5.0  3.6  1.4  0.2    Iris-setosa
# 5   5.4  3.9  1.7  0.4    Iris-setosa
# 6   4.6  3.4  1.4  0.3    Iris-setosa
# 7   5.0  3.4  1.5  0.2    Iris-setosa
# 8   4.4  2.9  1.4  0.2    Iris-setosa
# 9   4.9  3.1  1.5  0.1    Iris-setosa
# 10  5.4  3.7  1.5  0.2    Iris-setosa

# %% [markdown]
# Q7

# %%
df_auto.iloc[-1]
# Out:
# SL                           5.9
# SW                           3.0
# PL                           5.1
# PW                           1.8
# Classification    Iris-virginica
# Name: 149, dtype: object

# %% [markdown]
# Q8

# %%
df_auto.loc[25:30,["PL"]]
# Out:
#      PL
# 25  1.6
# 26  1.6
# 27  1.5
# 28  1.4
# 29  1.6
# 30  1.6

# %%
df_auto.loc[25:30,["PW"]]
# Out:
#      PW
# 25  0.2
# 26  0.4
# 27  0.2
# 28  0.2
# 29  0.2
# 30  0.2

# %% [markdown]
# Q9

# %%
df_auto.iloc[:10,[0,1]]
# Out:
#     SL   SW
# 0  5.1  3.5
# 1  4.9  3.0
# 2  4.7  3.2
# 3  4.6  3.1
# 4  5.0  3.6
# 5  5.4  3.9
# 6  4.6  3.4
# 7  5.0  3.4
# 8  4.4  2.9
# 9  4.9  3.1

# %% [markdown]
# Q10

# %%
df_auto.loc[1,:]
# Out:
# SL                        4.9
# SW                        3.0
# PL                        1.4
# PW                        0.2
# Classification    Iris-setosa
# Name: 1, dtype: object
